# %%
import pandas as pd
import os

# %%
a = pd.ExcelFile('Ecommerce_data.xlsx')
a

# %%
print(a.sheet_names)
# Out:
# ['Orders', 'Returns', 'People']

# %%
orders = pd.read_excel(a, 'Orders')
returns = pd.read_excel(a, 'Returns')
people = pd.read_excel(a, 'People')

# %%
orders.head()
returns.head()
people.head()
# Out:
#               Person           Region
# 0  Marilène Rousseau        Caribbean
# 1   Andile Ihejirika   Central Africa
# 2  Nicodemo Bautista  Central America
# 3     Cansu Peynirci     Central Asia
# 4         Lon Bonher       Central US

# %%
merged = pd.merge(orders, returns, on='Order ID')
merged
# Out:
#       Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 1      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   35040  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2216   35038  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36974  CA-2012-ZC21910140-41271 2012-12-28 2013-01-04  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
#        Customer ID     Customer Name    Segment  Postal Code           City  \
# 0      PB-19210127    Phillip Breyer  Corporate          NaN         Taipei
# 1      PB-19210127    Phillip Breyer  Corporate          NaN         Taipei
# 2      PB-19210127    Phillip Breyer  Corporate          NaN         Taipei
# 3      PB-19210127    Phillip Breyer  Corporate          NaN         Taipei
# 4      PB-19210127    Phillip Breyer  Corporate          NaN         Taipei
# ...            ...               ...        ...          ...            ...
# 2215  WB-218501406     William Brown   Consumer      10011.0  New York City
# 2216  WB-218501406     William Brown   Consumer      10011.0  New York City
# 2217    SJ-2021582      Sarah Jordon   Consumer          NaN     Hermosillo
# 2218  ZC-219101402  Zuschuss Carroll   Consumer      60610.0        Chicago
# 2219     PM-894038    Paul MacIntyre   Consumer          NaN     Alexandria
#
#       ...     Sales Quantity Discount    Profit Shipping Cost Order Priority  \
# 0     ...  1715.160        2      0.0  720.3600       725.570       Critical
# 1     ...  2197.500        5      0.0  153.7500       627.270       Critical
# 2     ...  1356.030        3      0.0  311.8500       458.970       Critical
# 3     ...   882.150        5      0.0  114.6000       203.920       Critical
# 4     ...   148.320        3      0.0   68.2200        25.480       Critical
# ...   ...       ...      ...      ...       ...           ...            ...
# 2215  ...    49.536        3      0.2   17.3376         2.670         Medium
# 2216  ...    16.520        4      0.0    7.5992         1.690         Medium
# 2217  ...   181.116        9      0.4  -75.5640         1.085         Medium
# 2218  ...    38.976        3      0.6  -50.6688         5.290            Low
# 2219  ...    25.830        1      0.0    9.0300         1.050         Medium
#
#      Unnamed: 24 Unnamed: 25  Returned         Region_y
# 0            NaN         NaN       Yes     Eastern Asia
# 1            NaN         NaN       Yes     Eastern Asia
# 2            NaN         NaN       Yes     Eastern Asia
# 3            NaN         NaN       Yes     Eastern Asia
# 4            NaN         NaN       Yes     Eastern Asia
# ...          ...         ...       ...              ...
# 2215         NaN         NaN       Yes       Eastern US
# 2216         NaN         NaN       Yes       Eastern US
# 2217         NaN         NaN       Yes  Central America
# 2218         NaN         NaN       Yes       Central US
# 2219         NaN         NaN       Yes     North Africa
#
# [2220 rows x 28 columns]

# %%
merged.shape
# Out:
# (2220, 28)

# %%
merged.isnull().any().sum()
# Out:
# 3

# %%
b = merged.dropna(axis=1)

# %%
b.shape
# Out:
# (2220, 25)

# %%
list(b)
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'City',
#  'State',
#  'Country',
#  'Region_x',
#  'Market',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Order Priority',
#  'Returned',
#  'Region_y']

# %% [markdown]
# # 1.What is the total value of the order that was returned?

# %%
total_returned_value = b['Sales'].sum()
print('The Total Returned Value is',total_returned_value)
# Out:
# The Total Returned Value is 525932.22736

# %% [markdown]
# # 2.What is the total returned value by region?

# %%
returned_value_by_region = b.groupby(['Region_y'])[['Sales']].sum()
returned_value_by_region
# Out:
#                          Sales
# Region_y
# Caribbean           9679.32828
# Central Africa      4038.48000
# Central America    44334.79916
# Central Asia         359.03100
# Central US         23306.14500
# Eastern Africa      2026.44000
# Eastern Asia       47798.04300
# Eastern Canada      2639.91000
# Eastern Europe      9501.21000
# Eastern US         23477.32600
# North Africa       10193.37000
# Northern Europe    17768.64000
# Oceania            46943.33100
# South America      29845.11212
# Southeastern Asia  36967.09830
# Southern Africa     7321.86000
# Southern Asia      25159.36500
# Southern Europe    34226.34300
# Southern US        17024.59700
# Western Africa      3928.15800
# Western Asia       11737.63800
# Western Canada       676.50000
# Western Europe     72669.48450
# Western US         44310.01800

# %% [markdown]
# # 3. What is the total returned value for category and sub_category using product id?

# %%
returned_value_by_category = merged.groupby(['Category', 'Sub-Category'])[['Sales']].sum()
returned_value_by_category
# Out:
#                                     Sales
# Category        Sub-Category
# Furniture       Bookcases     60710.99170
#                 Chairs        57439.11790
#                 Furnishings   16581.79860
#                 Tables        33283.15700
# Office Supplies Appliances    32975.10160
#                 Art           16221.50620
#                 Binders       23571.83300
#                 Envelopes      6784.22590
#                 Fasteners      3098.36380
#                 Labels         3349.15170
#                 Paper          9928.68380
#                 Storage       52938.56010
#                 Supplies       8327.68320
# Technology      Accessories   33991.09180
#                 Copiers       65145.83696
#                 Machines      32550.62610
#                 Phones        69034.49800

# %% [markdown]
# # 4. What is total number of products returned whose unit price is more than 100dollars?

# %%
b['Unit Price'] = b['Sales'] / b['Quantity']
b
# Out:
# C:\Users\vinod\AppData\Local\Temp\ipykernel_18096\117717015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['Unit Price'] = b['Sales'] / b['Quantity']
#       Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 1      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   35040  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2216   35038  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36974  CA-2012-ZC21910140-41271 2012-12-28 2013-01-04  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
#        Customer ID     Customer Name    Segment           City  \
# 0      PB-19210127    Phillip Breyer  Corporate         Taipei
# 1      PB-19210127    Phillip Breyer  Corporate         Taipei
# 2      PB-19210127    Phillip Breyer  Corporate         Taipei
# 3      PB-19210127    Phillip Breyer  Corporate         Taipei
# 4      PB-19210127    Phillip Breyer  Corporate         Taipei
# ...            ...               ...        ...            ...
# 2215  WB-218501406     William Brown   Consumer  New York City
# 2216  WB-218501406     William Brown   Consumer  New York City
# 2217    SJ-2021582      Sarah Jordon   Consumer     Hermosillo
# 2218  ZC-219101402  Zuschuss Carroll   Consumer        Chicago
# 2219     PM-894038    Paul MacIntyre   Consumer     Alexandria
#
#                 State  ...                                       Product Name  \
# 0         Taipei City  ...        Lesro Conference Table, with Bottom Storage
# 1         Taipei City  ...                       Safco Classic Bookcase, Pine
# 2         Taipei City  ...             Lesro Round Table, with Bottom Storage
# 3         Taipei City  ...               Office Star Swivel Stool, Adjustable
# 4         Taipei City  ...                            Okidata Calculator, Red
# ...               ...  ...                                                ...
# 2215         New York  ...  Square Ring Data Binders, Rigid 75 Pt. Covers,...
# 2216         New York  ...           #10 Gummed Flap White Envelopes, 100/Box
# 2217           Sonora  ...                             Deflect-O Clock, Black
# 2218         Illinois  ...           Tenex Chairmats For Use with Hard Floors
# 2219  Al Iskandariyah  ...              Sanford Pencil Sharpener, Fluorescent
#
#          Sales Quantity Discount    Profit Shipping Cost Order Priority  \
# 0     1715.160        2      0.0  720.3600       725.570       Critical
# 1     2197.500        5      0.0  153.7500       627.270       Critical
# 2     1356.030        3      0.0  311.8500       458.970       Critical
# 3      882.150        5      0.0  114.6000       203.920       Critical
# 4      148.320        3      0.0   68.2200        25.480       Critical
# ...        ...      ...      ...       ...           ...            ...
# 2215    49.536        3      0.2   17.3376         2.670         Medium
# 2216    16.520        4      0.0    7.5992         1.690         Medium
# 2217   181.116        9      0.4  -75.5640         1.085         Medium
# 2218    38.976        3      0.6  -50.6688         5.290            Low
# 2219    25.830        1      0.0    9.0300         1.050         Medium
#
#       Returned         Region_y  Unit Price
# 0          Yes     Eastern Asia     857.580
# 1          Yes     Eastern Asia     439.500
# 2          Yes     Eastern Asia     452.010
# 3          Yes     Eastern Asia     176.430
# 4          Yes     Eastern Asia      49.440
# ...        ...              ...         ...
# 2215       Yes       Eastern US      16.512
# 2216       Yes       Eastern US       4.130
# 2217       Yes  Central America      20.124
# 2218       Yes       Central US      12.992
# 2219       Yes     North Africa      25.830
#
# [2220 rows x 26 columns]

# %%
c = b[b['Unit Price'] > 100]
total_returned_products = c['Quantity'].sum()
print('The Total Returned Products is', total_returned_products)
# Out:
# The Total Returned Products is 1607

# %% [markdown]
# # 5. How many of the orders deliverd on the same day, 7days, 15days and >30 days?

# %%
b['delivery_days'] = (b['Ship Date'] - b['Order Date']).dt.days
b
# Out:
# C:\Users\vinod\AppData\Local\Temp\ipykernel_18096\3639095050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['delivery_days'] = (b['Ship Date'] - b['Order Date']).dt.days
#       Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 1      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   35040  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2216   35038  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36974  CA-2012-ZC21910140-41271 2012-12-28 2013-01-04  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
#        Customer ID     Customer Name    Segment           City  \
# 0      PB-19210127    Phillip Breyer  Corporate         Taipei
# 1      PB-19210127    Phillip Breyer  Corporate         Taipei
# 2      PB-19210127    Phillip Breyer  Corporate         Taipei
# 3      PB-19210127    Phillip Breyer  Corporate         Taipei
# 4      PB-19210127    Phillip Breyer  Corporate         Taipei
# ...            ...               ...        ...            ...
# 2215  WB-218501406     William Brown   Consumer  New York City
# 2216  WB-218501406     William Brown   Consumer  New York City
# 2217    SJ-2021582      Sarah Jordon   Consumer     Hermosillo
# 2218  ZC-219101402  Zuschuss Carroll   Consumer        Chicago
# 2219     PM-894038    Paul MacIntyre   Consumer     Alexandria
#
#                 State  ...     Sales Quantity Discount    Profit  \
# 0         Taipei City  ...  1715.160        2      0.0  720.3600
# 1         Taipei City  ...  2197.500        5      0.0  153.7500
# 2         Taipei City  ...  1356.030        3      0.0  311.8500
# 3         Taipei City  ...   882.150        5      0.0  114.6000
# 4         Taipei City  ...   148.320        3      0.0   68.2200
# ...               ...  ...       ...      ...      ...       ...
# 2215         New York  ...    49.536        3      0.2   17.3376
# 2216         New York  ...    16.520        4      0.0    7.5992
# 2217           Sonora  ...   181.116        9      0.4  -75.5640
# 2218         Illinois  ...    38.976        3      0.6  -50.6688
# 2219  Al Iskandariyah  ...    25.830        1      0.0    9.0300
#
#      Shipping Cost Order Priority Returned         Region_y  Unit Price  \
# 0          725.570       Critical      Yes     Eastern Asia     857.580
# 1          627.270       Critical      Yes     Eastern Asia     439.500
# 2          458.970       Critical      Yes     Eastern Asia     452.010
# 3          203.920       Critical      Yes     Eastern Asia     176.430
# 4           25.480       Critical      Yes     Eastern Asia      49.440
# ...            ...            ...      ...              ...         ...
# 2215         2.670         Medium      Yes       Eastern US      16.512
# 2216         1.690         Medium      Yes       Eastern US       4.130
# 2217         1.085         Medium      Yes  Central America      20.124
# 2218         5.290            Low      Yes       Central US      12.992
# 2219         1.050         Medium      Yes     North Africa      25.830
#
#       delivery_days
# 0                 3
# 1                 3
# 2                 3
# 3                 3
# 4                 3
# ...             ...
# 2215              6
# 2216              6
# 2217              3
# 2218              7
# 2219              4
#
# [2220 rows x 27 columns]

# %%
same_day = b[b['delivery_days'] == 0].shape[0]
within_7_days = b[(b['delivery_days'] > 0) & (b['delivery_days'] <= 7)].shape[0]
within_15_days = b[(b['delivery_days'] > 7) & (b['delivery_days'] <= 15)].shape[0]
more_than_30_days = b[b['delivery_days'] > 30].shape[0]

# %%
print(f"Same Day: {same_day}")
print(f"Within 7 Days: {within_7_days}")
print(f"Within 15 Days: {within_15_days}")
print(f"More than 30 Days: {more_than_30_days}")
# Out:
# Same Day: 115
# Within 7 Days: 2105
# Within 15 Days: 0
# More than 30 Days: 0

# %% [markdown]
# # 6. Check the relationship between price and quantity?

# %%
from scipy.stats import pearsonr
pearsonr(b['Unit Price'],b['Quantity'])
# Out:
# PearsonRResult(statistic=-0.02833034445143083, pvalue=0.18208808203216745)

# %% [markdown]
# ### Inference
# ### The r value = -0.028 so it is a negative correlation. It Indicates almost no linear relationship between the unit price and quantity.
# ### A negative value suggests that there might be a very weak inverse relationship, meaning as the price increases, the quantity might decrease slightly, but the effect is negligible.

# %% [markdown]
# # 7. Use the calculation from question 5 and order priority. Check is there any relationship between order priority and days taken.

# %%
from scipy import stats

# %%
priority_delivery_stats = b.groupby('Order Priority')['delivery_days'].describe()
print(priority_delivery_stats)
# Out:
#                  count      mean       std  min  25%  50%  75%  max
# Order Priority
# Critical         188.0  1.750000  1.135829  0.0  1.0  2.0  3.0  3.0
# High             643.0  3.205288  1.453807  0.0  2.0  4.0  4.0  5.0
# Low              125.0  6.552000  0.499290  6.0  6.0  7.0  7.0  7.0
# Medium          1264.0  4.528481  1.393053  0.0  4.0  5.0  5.0  7.0

# %%
anova_result = stats.f_oneway(
    b[b['Order Priority'] == 'Low']['delivery_days'],
    b[b['Order Priority'] == 'Medium']['delivery_days'],
    b[b['Order Priority'] == 'High']['delivery_days'],
    b[b['Order Priority'] == 'Critical']['delivery_days'])

print(f"ANOVA result: {anova_result}")
# Out:
# ANOVA result: F_onewayResult(statistic=456.90010105295534, pvalue=4.523164187330846e-231)

# %% [markdown]
# ### The p-value from the ANOVA test is less than 0.05, it indicates a statistically significant difference in delivery times between different order priority levels.
